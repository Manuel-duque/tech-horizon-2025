# %%
import pandas as pd
import matplotlib.pyplot as plt

artistas = ["Beyoncé", "Sia", "Anitta", "Adele", "Eminem", "Ed Sheeran", "Harpa Cristia", "Coldplay", "Pink", "Taylor Swift"]
fans = [230, 140, 90, 200, 220, 280, 50, 190, 100, 350]

plt.figure(figsize=(10,6))
plt.bar(artistas, fans, color="#1f77b4")
plt.gcf().set_facecolor("#FAF3E0")

plt.title("Popularidad de Artistas")
plt.xlabel("Artistas")
plt.ylabel("Número de Fans (en millones)")
plt.xticks(rotation=55)

plt.tight_layout()
plt.grid(True)
plt.savefig("popularidad.png")
plt.show()

# %%
genre_popularity = df.groupby("Genres")["Popularity"].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(8,5))
plt.plot(genre_popularity.index, genre_popularity.values, marker="s", color="purple")
plt.gcf().set_facecolor("#EDE7F6")
plt.xticks(rotation=45)
plt.title("Promedio de Popularidad por Género (Top 10)")
plt.ylabel("Popularidad Promedio")
plt.grid(True)
plt.savefig("pupularidad_por_genero.png")
plt.show()

# %%
genre_songs = df.groupby("Genres")["Songs"].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(8,5))

plt.plot(genre_songs.index, genre_songs.values, marker="d", color="red")
plt.gcf().set_facecolor("#FAF3E0")

plt.xticks(rotation=45)
plt.title("Promedio de canciones por género (Top 10)")
plt.ylabel("Canciones Promedio")
plt.grid(True)
plt.savefig("canciones_por_genero.png")
plt.show()
