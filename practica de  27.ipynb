# %%
pelicula = {
    "Título": "Sonic the Hedgehog 2",
    "Director": "Jeff Fowler",
    "Año": 2022,
    "Género": "Acción / Aventura / Comedia",
    "Calificación": 7.6,
    "Actores principales": [
        "James Marsden",  # Tom Wachowski
        "Jim Carrey",    # Dr. Ivo Robotnik
        "Ben Schwartz",  # Sonic the Hedgehog (voz)
        "Tika Sumpter",  # Maddie Wachowski
        "Idris Elba"     # Knuckles the Echidna (voz)
    ]
}

print("Información de la película:")
print("Título:", pelicula.get("Título"))
print("Director:", pelicula.get("Director"))
print("Año:", pelicula.get("Año"))
print("Género:", pelicula.get("Género"))
print("Calificación:", pelicula.get("Calificación"))
print("Actores principales:", ", ".join(pelicula.get("Actores principales")))
# Out:
# Información de la película:
# Título: Sonic the Hedgehog 2
# Director: Jeff Fowler
# Año: 2022
# Género: Acción / Aventura / Comedia
# Calificación: 7.6
# Actores principales: James Marsden, Jim Carrey, Ben Schwartz, Tika Sumpter, Idris Elba
